# %%
# !git clone https://github.com/yeeyangtee/private-data-generation.git
# Out:
# Cloning into 'private-data-generation'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 103 (delta 35), reused 84 (delta 20), pack-reused 0
# Receiving objects: 100% (103/103), 1.21 MiB | 6.01 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# !cd private-data-generation/

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
logfile = '/content/log_churn_DPWGAN_1623407005_0.5.csv' # MODIFY THIS!
df = pd.read_csv(logfile, names = ['Disc Loss Real', 'Disc Loss Fake','Gen Loss', 'Epsilon'])

# %%
sns.lineplot(data =df.loc[:,['Disc Loss Real', 'Disc Loss Fake','Gen Loss']])

# %%
sns.lineplot(data =df['Epsilon'])
