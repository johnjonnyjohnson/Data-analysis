# %%
# !git clone https://github.com/yeeyangtee/private-data-generation.git
# Out:
# Cloning into 'private-data-generation'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 98 (delta 31), reused 82 (delta 19), pack-reused 0
# Unpacking objects: 100% (98/98), done.

# %%
cd private-data-generation/
# Out:
# /content/private-data-generation/private-data-generation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
logfile = '/content/log_churn_PATEGAN_1623091805_1.csv' # MODIFY THIS!
df = pd.read_csv(logfile, names = ['SDisc Loss', 'Gen Loss', 'Epsilon'])

# %%
sns.lineplot(data =df.loc[:,['SDisc Loss','Gen Loss']])

# %%
sns.lineplot(data =df['Epsilon'])
# Out:
# <AxesSubplot:ylabel='Epsilon'>
