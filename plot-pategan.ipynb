# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
logfile = 'logs/log_churn_PATEGAN.csv'
df = pd.read_csv(logfile, names = ['Disc Loss', 'Gen Loss', 'Epsilon'])

# %%
sns.lineplot(data =df.loc[:,['Disc Loss','Gen Loss']])
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data =df['Epsilon'])
# Out:
# <AxesSubplot:ylabel='Epsilon'>
